# %%
from ast import increment_lineno
# creating numpy array and importing sys, time
import numpy as np
import sys
import time
arr1 = np.array([1,2,3,4,5,6])
arr1
type(arr1)

arr2 = np.array([[1,2,3],[4,5,6]])
arr2

arr3 = np.zeros([2,3])
arr3
# arr3[1,2] = 1
# arr3

arr4 = np.ones([3,3])
# arr4[0] = 2
arr4

arr5 = np.identity(3)
arr5

arr6 = np.arange(9)
# arr6 = np.arange(10,100)
arr6

arr7 = np.linspace(10,20,10)
arr7

arr8 = arr7.copy()
arr8
"End of lecture 3 : Creating N-d Arrays"
# Properties of N-d Arays:
arr1.shape
arr9 = np.zeros([6,1])
arr9.shape
arr9.ndim
arr9.size #size gave no. of items in the arr
arr9.itemsize #item size gave the memory occupied by the datatype..?
arr9.astype('long')
"End of lecture 4 : Properties of N-d Arrays"
# Numpy Arrays vs Python Lists:
# Proof of Less Memory:
lista=range(100)
arr11 = np.arange(100)
# sys.getsizeof(lista) # 48
# sys.getsizeof(arr11) # 912

sys.getsizeof(87)*len(lista) # 2800
arr11.itemsize*arr11.size # gives 800 but lecture 5 minute 4:24 shows 400..?

# Proof of Fast Speed:
x=range(10000000)
y=range(10000000,20000000)

start_time = time.time()
c1=[x+y for x,y in zip(x,y)]
# print(time.time()-start_time)

a=np.arange(10000000)
b=np.arange(10000000,20000000)
start_time1 = time.time()
c2=a+b
print(time.time()-start_time)
print(time.time()-start_time1)
"End of Lecture 5 : Numpy Arrays vs Python Lists"

# Indexing, Slicing, and Iteration:
arr12 = np.arange(24).reshape(6,4)
arr12
arr12[4:6,2:4]

# for i in arr12:
#   print(i)

# for i in np.nditer(arr12):
#   print(i)

"End of Lecture 6 : Indexing, Slicing, and Iteration"

# Numpy Operations:
arr1 = np.array([1,2,3,4,5,6])
arr2 = np.array([4,5,6,7,8,9])
arr1-arr2
arr1*arr2
arr1*2
arr2>3

arr1 = np.arange(6).reshape(2,3)
arr2 = np.arange(6,12).reshape(3,2)
arr1.dot(arr2)

# arr1.dot(arr3 ) Gives Erorr
arr4[0,2] = 12
arr4.max()
arr4.min()
arr12.min(axis=0)
arr12.sum(axis=1)
np.sqrt(arr12)
np.std(arr12)
np.median(arr12)
np.mean(arr12)
np.sin(arr12)
np.exp(arr12)
arr12.astype('int')
"End of Lecture 7 : Array Operations"
# Reshaping Numpy Arrays:
arr4.ravel()
arr12.ravel()
arr12.transpose()

arr1= np.arange(6).reshape(2,3)
arr2= np.arange(12,18).reshape(2,3)
np.hstack((arr1,arr2))
np.vstack((arr1,arr2))
arr1
np.vsplit(arr1,2)
np.hsplit(arr1,3)
"End of Lecture 8 : Reshaping Numpy Arrays"

# Fancy Indexing in Arrays
arr8 = np.arange(24).reshape(6,4)
arr8[[0,2,4]]
arr8[:, [0,2,3]] # For columns
"End of Lecture 9 : Fancy Indexing"

# Indexing with Boolean Arrays:
arr = np.random.randint(low=1,high=100,size=20).reshape(4,5)
# (arr>50).shape
# arr[arr>50]
arr[(arr>50) & (arr%2!=0)]= 0
arr
"End of Lecture 10 : Indexing with Boolean Arrays"

# Plotting Graphs:
x=np.linspace(-40,40,100)
y=np.sin(x)
y.size
import matplotlib.pyplot as plt
# %matplotlib inline
# plt.plot(x,y)

y=x*x+2*x+6
# plt.plot(x,y)
"End of Lecture 11 : Plotting Graphs"

# Broadcasting
# Scenario 1
a1 = np.arange(5).reshape(1,5)
a2 = np.arange(10,20).reshape(2,5)
a1+a2 # works

# Scenario 2
a1 = np.arange(5).reshape(1,5)
a2 = np.arange(15).reshape(3,5)
a1+a2 # works

# Scenario 3
# a1 = np.arange(5).reshape(1,5)
# a2 = np.arange(14).reshape(2,7)
# a1+a2 (Will not work)

# Scenario 4
a1 = np.arange(3).reshape(1,3)
a2 = np.arange(3).reshape(3,1)
a1+a2 # works

# Scenario 5
a1 = np.arange(1).reshape(1,1)
a2 = np.arange(20).reshape(4,5)
a1+a2 # works

# Scenario 6
a1 = np.arange(4)
a2 = np.arange(20).reshape(5,4)
a1+a2 # works
"End of Lecture 12 : Broadcasting"

# Some Important Numpy Functions:
np.random.random()
np.random.random((2,3))
np.random.seed(1)
np.random.random()

np.random.uniform(2,10)
np.random.uniform(2,100,10).astype('int')

# np.random.randint(2,100)
a= np.random.randint(2,100,10)
np.max(a)
np.min(a)
np.argmax(a)
a[np.argmin(a)]
a[a%2==1] = -1
a

b = np.random.randint(1,50,6)
c=np.where(b%2==1, -1, b)
print(b,c)

c = np.random.randint(1,50,10)
c= np.sort(c)
c
np.percentile(c,99.8)
np.percentile(c,100)
"End of Numpy."
# Out:
# 0.9650533199310303
# 0.031614065170288086
# [23 14 42 10  8 23] [-1 14 42 10  8 -1]
# np.float64(48.0)
